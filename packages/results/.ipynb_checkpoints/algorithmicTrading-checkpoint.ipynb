# %%
from QLmodel.processing.data_management import load_data
from QLmodel.train_model import train_model
from QLmodel.config import config

# %%
import matplotlib.pyplot as plt

# %%
train, test = load_data(config.STOCKS+config.TARGET)

# %%
plt.plot(train['SPY'])
plt.plot(test['SPY'])
plt.show()

# %%
train_rewards, test_rewards = train_model()
# Out:
# C:\Users\skyst\anaconda3\envs\ml\lib\site-packages\numpy\core\fromnumeric.py:87: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\skyst\anaconda3\envs\ml\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# eps: 1/1000, train: 0.65566, test: 0.42037
# eps: 2/1000, train: 1.06805, test: 0.48013
# eps: 3/1000, train: 0.37275, test: 0.45224
# eps: 4/1000, train: 0.64447, test: 0.46045
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(train_rewards)
plt.plot(test_rewards)
plt.show()
